# %%
import getpass
from glob import glob
import os
from tqdm import tqdm

import numpy as np
import pandas as pd
import plotly.express as px
from scipy.stats import spearmanr, pearsonr
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_predict, LeaveOneOut
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
root_dir = os.path.join("/home/", getpass.getuser(), "bio_share/", "stegg_results/")

peptides = ["AVFDRKSDAK", "ELAGIGILTV", "FLCMKALLL", "GILGFVFTL", "LLWNGPMAV"]
tcrs = ["A11Vc", "A3V", "TCR1"]

energy_cols = ["fa_atr", "fa_rep", "fa_sol", "fa_intra_rep", "fa_intra_sol_xover4", "lk_ball_wtd", "fa_elec", "pro_close", "hbond_sr_bb", "hbond_lr_bb", "hbond_bb_sc", "hbond_sc", "dslf_fa13", "omega", "fa_dun", "p_aa_pp", "yhh_planarity", "ref", "rama_prepro"]
energy_weights = np.array([1.0, 0.55, 1.0, 0.005, 1.0, 1.0, 1.0, 1.25, 1.0, 1.0, 1.0, 1.0, 1.25, 0.6, 0.7, 0.4, 0.625, 1.0, 0.45])

# %%
def build_dataset(dataset: str, agg_method: str = "mean") -> pd.DataFrame:

    if dataset in peptides:
        case_dirs = glob(os.path.join(root_dir, "peptide_datasets", dataset, "*"))
    elif dataset in tcrs:
        case_dirs = glob(os.path.join(root_dir, "tcr_datasets", f"{dataset}_*"))

    data = dict()
    for case_dir in tqdm(case_dirs):
        case = os.path.basename(case_dir)
        energy_csv_fp = os.path.join(case_dir, "energy_terms.csv")
        if not os.path.exists(energy_csv_fp):
            continue
        energy_df = pd.read_csv(energy_csv_fp, index_col=0)
        if len(energy_df) == 0:
            continue
        term_matrix = energy_df[energy_cols].values
        if agg_method == "mean":
            agg_term_vector = term_matrix.mean(axis=0)
        elif agg_method == "medoid":
            medoid_i = np.linalg.norm(term_matrix - term_matrix.mean(axis=0), axis=1).argmin()
            agg_term_vector = term_matrix[medoid_i]
        elif agg_method == "energy":
            scores = (term_matrix * energy_weights).sum(axis=1)
            agg_term_vector = term_matrix[scores.argmin()]
        elif agg_method == "rand":
            agg_term_vector = term_matrix[np.random.randint(term_matrix.shape[0])]
        data[case] = {term: agg_term_vector[i] for i, term in enumerate(energy_cols)}

    energy_df = pd.DataFrame.from_dict(data, orient="index")

    ba_csv_fp = os.path.join("use_case_demo/", "peptide_datasets/" if dataset in peptides else "TCR_datasets/", f"{dataset}.csv")
    ba_df = pd.read_csv(ba_csv_fp, index_col=0)
    if dataset in peptides:
        ba_df.set_index(ba_df.CDR3a + "_" + ba_df.CDR3b + "_" + ba_df.peptide, inplace=True)
    elif dataset in tcrs:
        ba_df.index = [f"{dataset}_row{i + 1}" for i in range(len(ba_df))]
        ba_df["label"] = ba_df.activation

    if "split" not in ba_df.columns:
        ba_df = ba_df.sample(frac=1, random_state=1047)
        rand = np.random.rand(len(ba_df))
        ba_df["split"] = np.where(rand < 0.75, "train", np.where(rand < 0.875, "val", "test"))

    df = energy_df.merge(ba_df[["label", "split"]], how="inner", left_index=True, right_index=True)

    return df

# %%
# --- Model Definitions ---
# Classifiers that use "decision_function" or "predict_proba"

classifiers = {
    # Decision Function Classifiers (Need StandardScaler)
    "RidgeClassifier": {
        "model": make_pipeline(StandardScaler(), RidgeClassifier(random_state=42)),
        "method": "decision_function"
    },
    # Predict Proba Classifiers (Need StandardScaler)
    "LogisticRegression": {
        "model": make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear", random_state=42)),
        "method": "predict_proba"
    },
    "LinearSVC": {
        # LinearSVC only supports "decision_function"
        "model": make_pipeline(StandardScaler(), SVC(kernel="linear", random_state=42)),
        "method": "decision_function"
    },
    # "KernelSVC_RBF": {
    #     # "probability=True" is required for predict_proba in SVC
    #     "model": make_pipeline(StandardScaler(), SVC(kernel="rbf", probability=True, random_state=42)),
    #     "method": "predict_proba"
    # },
    # "KNeighborsClassifier": {
    #     "model": make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=5)),
    #     "method": "predict_proba"
    # },
    # # Naive Bayes Classifiers (Gaussian NB often benefits from scaling, Bernoulli NB does not strictly need it)
    # "GaussianNB": {
    #     "model": make_pipeline(StandardScaler(), GaussianNB()),
    #     "method": "predict_proba"
    # },
}


# --- Dataset Definitions (Remaining the same) ---
peptides = ["AVFDRKSDAK", "ELAGIGILTV", "FLCMKALLL", "GILGFVFTL", "LLWNGPMAV"]
tcrs = ["A11Vc", "A3V", "TCR1"]
# datasets = peptides
datasets = peptides + tcrs
loo = LeaveOneOut()
agg_method = "rand"

# --- Main Scoring Loop ---
print("--- ROC AUC Results by Dataset and Classifier ---")

for dataset in datasets:

    try:
        df = build_dataset(dataset, agg_method=agg_method)
    except:
        continue

    df["label"] = df["label"].apply(lambda x: x > 0)
    energy_term_cols = df.drop(["label", "split"], axis=1, errors="ignore").columns
    df.to_csv(f"{dataset}.csv")

    # px.box(df, x=energy_term_cols).show()

    X = df[energy_term_cols].values
    y = df.label.values

    print(f"\n🔬 **Dataset: {dataset}**")

    # 2. Iterate Over All Classifiers
    for name, params in classifiers.items():
        model = params["model"]
        method = params["method"]

        try:
            # Use cross_val_predict to get the cross-validated scores
            y_scores = cross_val_predict(
                estimator=model,
                X=X,
                y=y,
                cv=loo,
                method=method
            )

            # Select the positive class score (index 1) for "predict_proba" output
            if method == "predict_proba":
                y_scores = y_scores[:, 1]

            # Calculate the ROC AUC score
            full_auc_score = roc_auc_score(y, y_scores)

            # Print the result
            print(f"  - **{name}** (LOOCV combined ROC AUC): {full_auc_score:.4f}")

        except Exception as e:
            # Catch errors like missing probability support or convergence issues
            print(f"  - **{name}** (LOOCV combined ROC AUC): FAILED ({e.__class__.__name__})")

print("\n--- Analysis Complete ---")

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import numpy as np

# --- Dataset Definitions (Remaining the same) ---
peptides = ["ELAGIGILTV", "FLCMKALLL", "GILGFVFTL", "LLWNGPMAV"]
tcrs = ["A11Vc", "A3V", "TCR1"]
datasets = peptides + tcrs

# --- Main Feature Importance Loop ---
print("--- LinearSVC Feature Importance Analysis ---")

for dataset in datasets:
    # 1. Load and Prepare Data
    try:
        df = pd.read_csv(f"{dataset}.csv", index_col=0)
    except FileNotFoundError:
        print(f"Skipping {dataset}: File not found.")
        continue

    df["label"] = df["label"].apply(lambda x: x > 0)
    energy_term_cols = df.drop(["label", "split"], axis=1, errors="ignore").columns

    X = df[energy_term_cols].values
    y = df.label.values

    print(f"\n🧠 **Dataset: {dataset}**")

    # 2. Define and Train the LinearSVC Model
    # Use SVC with a "linear" kernel. This is equivalent to LinearSVC but allows for a pipeline.
    # We must first scale the data so the coefficients are comparable.
    model = make_pipeline(StandardScaler(), SVC(kernel="linear", random_state=42))

    # Fit the model on the entire dataset to determine general feature importance
    model.fit(X, y)

    # 3. Extract and Interpret Coefficients
    # The coefficients are stored in the last step of the pipeline (the SVC estimator)
    # The .named_steps["svc"] accesses the SVC object inside the pipeline
    # For binary classification, coef_ has shape (1, n_features). We use the first row [0].

    # Extract coefficients
    coefficients = model.named_steps["svc"].coef_[0]

    # Get feature names
    feature_names = np.array(energy_term_cols)

    # Calculate absolute coefficients for ranking importance
    abs_coefficients = np.abs(coefficients)

    # Sort features by absolute coefficient magnitude (descending order)
    sorted_indices = np.argsort(abs_coefficients)[::-1]

    # 4. Display the Top 5 Most Important Features
    top_n = 5
    print(f"Top {top_n} Most Important Features (based on absolute coefficient value):")

    # Create a list of tuples (feature_name, coefficient_value)
    importance_list = [
        (feature_names[i], coefficients[i])
        for i in sorted_indices[:top_n]
    ]

    # Print in a formatted way
    for i, (feature, coef) in enumerate(importance_list):
        # Indicate the direction: positive coefficient means higher feature value -> positive class (True)
        # negative coefficient means higher feature value -> negative class (False)
        direction = "Positive Influence" if coef > 0 else "Negative Influence"
        print(f"  {i+1}. **{feature}**: Coef={coef:.4f} ({direction})")

print("\n--- Analysis Complete ---")

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import numpy as np

# --- Dataset Definitions (Remaining the same) ---
peptides = ["ELAGIGILTV", "FLCMKALLL", "GILGFVFTL", "LLWNGPMAV"]
tcrs = ["A11Vc", "A3V", "TCR1"]
datasets = peptides + tcrs

# Dictionary to store all coefficients: {feature_name: {dataset_name: coefficient}}
all_coefficients = {}

# List to keep track of all unique feature names
all_feature_names = set()

# --- 1. Train Models and Collect Coefficients ---
print("--- 1. Training LinearSVC and Collecting Coefficients ---")

for dataset in datasets:
    try:
        df = pd.read_csv(f"{dataset}.csv", index_col=0)
    except FileNotFoundError:
        print(f"Skipping {dataset}: File not found.")
        continue

    df["label"] = df["label"].apply(lambda x: x > 0)
    energy_term_cols = df.drop(["label", "split"], axis=1, errors="ignore").columns

    X = df[energy_term_cols].values
    y = df.label.values

    # 2. Define and Train the LinearSVC Model (using SVC with linear kernel)
    # The pipeline ensures data is scaled before fitting, making coefficients comparable.
    model = make_pipeline(StandardScaler(), SVC(kernel="linear", random_state=42))
    model.fit(X, y)

    # 3. Extract Coefficients
    coefficients = model.named_steps["svc"].coef_[0]

    # Store coefficients for this dataset
    for feature_name, coef_value in zip(energy_term_cols, coefficients):
        all_feature_names.add(feature_name)
        if feature_name not in all_coefficients:
            all_coefficients[feature_name] = {}
        all_coefficients[feature_name][dataset] = coef_value

# --- 2. Organize and Rank Features in a DataFrame ---

# Convert the nested dictionary into a Pandas DataFrame
# The DataFrame is structured with Features as the index and Datasets as columns
coef_df = pd.DataFrame(all_coefficients).T.fillna(0) # Transpose and fill missing values with 0

# Calculate the average absolute coefficient across all datasets for ranking
# This serves as the "general importance" measure.
coef_df["Avg_Abs_Coefficient"] = coef_df.abs().mean(axis=1)

# Sort the DataFrame by the average absolute coefficient (most important first)
coef_df_ranked = coef_df.sort_values(by="Avg_Abs_Coefficient", ascending=False)

# Drop the intermediate "Avg_Abs_Coefficient" column for the final clean table
final_importance_table = coef_df_ranked.drop(columns=["Avg_Abs_Coefficient"])


# --- 3. Format and Display the Final Table ---
print("\n--- 2. Combined Feature Impact Table (LinearSVC Coefficients) ---")

# Apply formatting to the coefficients: sign + magnitude
def format_coef(coef):
    """Formats the coefficient into a readable string with sign and magnitude."""
    if coef == 0:
        return "-"
    # The "influence" emoji is based on the sign
    emoji = "⬆️" if coef > 0 else "⬇️"
    return f"{coef:+.4f} {emoji}"

# Apply the formatter to the entire table
styled_table = final_importance_table.applymap(format_coef)

# Add a "Rank" column
styled_table.insert(0, "Rank", np.arange(1, len(styled_table) + 1))


print("\n**Feature Impact Across All Datasets (Ranked by Average Absolute Coefficient)**")
print("  - **Positive Coefficient (+):** Higher feature value promotes the \"True\" (positive) label. ⬆️")
print("  - **Negative Coefficient (-):** Higher feature value promotes the \"False\" (negative) label. ⬇️")
print("  - **Format:** [Coefficient Value] [Influence Direction]")
print("-" * 100)
print(styled_table.to_markdown(numalign="left", stralign="left"))
print("-" * 100)

# %%
import pandas as pd

# --- Configuration and Setup ---

# Dataset definitions
peptides = ["ELAGIGILTV", "FLCMKALLL", "GILGFVFTL", "LLWNGPMAV"]
tcrs = ["A11Vc", "A3V", "TCR1"]
datasets = peptides + tcrs

# Features to calculate quartiles for
quartile_features = ["fa_sol", "fa_atr", "ref"]

# Percentiles to calculate
percentiles = [0.25, 0.50, 0.75]


print("--- Dataset Class Distribution and Feature Quartiles Analysis ---")

for dataset in datasets:
    try:
        df = pd.read_csv(f"{dataset}.csv", index_col=0)
    except FileNotFoundError:
        print(f"\nSkipping {dataset}: File not found.")
        continue

    # Convert "label" to a boolean for clear positive/negative separation
    df["label"] = df["label"].apply(lambda x: x > 0)

    print(f"\n📈 **Dataset: {dataset}**")

    # 1. Count Positives and Negatives
    positive_count = df["label"].sum()
    negative_count = len(df) - positive_count

    print(f"  - **Total Samples:** {len(df)}")
    print(f"  - **Positive Samples (True):** {positive_count}")
    print(f"  - **Negative Samples (False):** {negative_count}")

    # 2. Split data by class
    df_positives = df[df["label"] == True]
    df_negatives = df[df["label"] == False]

    # 3. Calculate and Print Quartiles

    # Prepare a list of dataframes and class names for iteration
    data_to_analyze = [
        (df_positives, "Positive (True)"),
        (df_negatives, "Negative (False)")
    ]

    for data_subset, class_name in data_to_analyze:

        # Calculate descriptive statistics (quartiles are part of this)
        # Use .T to transpose the output so features are rows
        quartile_data = data_subset[quartile_features].quantile(percentiles).T

        # Rename the columns for clarity (25%, Median, 75%)
        quartile_data.columns = ["25th % (Q1)", "50th % (Median / Q2)", "75th % (Q3)"]

        print(f"\n  -- **{class_name} Samples ({len(data_subset)} total) Feature Quartiles:**")

        # Print the table using markdown for clear formatting
        print(quartile_data.to_markdown(numalign="right"))

print("\n--- Analysis Complete ---")
