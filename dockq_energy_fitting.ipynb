# %%
import getpass
from glob import glob
import os
from tqdm import tqdm

import pandas as pd
import plotly.express as px
from scipy.stats import spearmanr, pearsonr
from sklearn.cross_decomposition import PLSRegression

# %%
root_dir = os.path.join("/home/", getpass.getuser(), "bio_share/", "stegg_results/")
ensemble_dirs = glob(os.path.join(root_dir, "stcrdab/*"))
pdb_ids = [x.split("/")[-2 if x.endswith("/") else -1] for x in ensemble_dirs]

energy_terms = list()
geo_terms = list()
feature_dfs = list()
for (ensemble_dir, pdb_id) in zip(ensemble_dirs, pdb_ids):
    energy_term_df = pd.read_csv(os.path.join(ensemble_dir, "energy_terms.csv"))
    energy_term_df.set_index(pdb_id + energy_term_df["Unnamed: 0"].str[:-4], inplace=True)
    energy_term_df.drop("Unnamed: 0", axis=1, inplace=True)
    energy_terms = energy_term_df.columns
    geo_df = pd.read_csv(os.path.join(ensemble_dir, "geo.csv"))
    geo_df.set_index(pdb_id + geo_df.pdb_name, inplace=True)
    geo_df.drop("pdb_name", axis=1, inplace=True)
    geo_terms = geo_df.columns
    feature_df = pd.concat([energy_term_df, geo_df], axis=1)
    feature_dfs.append(feature_df)

feature_df = pd.concat(feature_dfs)
feature_df.drop_duplicates(inplace=True)
feature_df.sort_index()
feature_df
# Out:
#                            fa_atr       fa_rep       fa_sol  fa_intra_rep  \
# 8EO8_complex_143_roi -2320.055460  1234.696175  1568.605922    973.118948
# 8EO8_complex_147_roi -2337.947409  1217.370873  1591.203020    984.388912
# 8EO8_complex_110_roi -2332.429734  1304.146641  1602.097439    956.956673
# 8EO8_complex_181_roi -2358.158488  1229.246572  1623.073202   1002.821463
# 8EO8_complex_5_roi   -2429.327773  1183.660641  1650.352612    980.637605
# ...                           ...          ...          ...           ...
# 6VRM_complex_2_roi   -2442.170327  1626.268022  1637.324889   1030.991801
# 6VRM_complex_49_roi  -2393.877722  1474.000488  1625.137759   1037.944011
# 6VRM_complex_60_roi  -2430.830083  1343.502624  1639.858301   1015.701515
# 6VRM_complex_61_roi  -2388.332963  2718.255656  1490.431770   1231.005285
# 6VRM_complex_78_roi  -2379.220700  1390.280775  1618.996458   1015.719889
#
#                       fa_intra_sol_xover4  lk_ball_wtd     fa_elec  pro_close  \
# ...

# %%
score_df = pd.read_csv("stcrdab_scores_filtered.csv", index_col=0)
score_df
# Out:
#                      pdb_id     DockQ        F1     iRMSD      LRMSD  \
# 1AO7_complex_100_roi   1AO7  0.486835  0.444444  2.763904   3.993340
# 1AO7_complex_101_roi   1AO7  0.343916  0.406250  4.034967   9.171524
# 1AO7_complex_102_roi   1AO7  0.336972  0.320000  4.525404   6.429585
# 1AO7_complex_103_roi   1AO7  0.566692  0.592593  2.071850   4.190820
# 1AO7_complex_104_roi   1AO7  0.381042  0.392857  4.343991   6.137761
# ...                     ...       ...       ...       ...        ...
# 8YE4_complex_96_roi    8YE4  0.199169  0.050000  4.276842   9.540469
# 8YE4_complex_97_roi    8YE4  0.290311  0.255319  4.007089   8.930815
# 8YE4_complex_98_roi    8YE4  0.130761  0.157895  6.957770  16.411849
# 8YE4_complex_99_roi    8YE4  0.123808  0.142857  8.743062  16.663863
# 8YE4_complex_9_roi     8YE4  0.091863  0.040000  7.638807  17.380767
#
#                           fnat  nat_correct  nat_total   fnonnat  \
# 1AO7_complex_100_roi  0.413793           12         29  0.520000
# ...

# %%
# there is one extra (unscored) model in 8NE8
feature_df = feature_df.loc[score_df.index]
feature_df
# Out:
#                            fa_atr       fa_rep       fa_sol  fa_intra_rep  \
# 1AO7_complex_100_roi -2356.978448  1357.951859  1579.891104    970.809611
# 1AO7_complex_101_roi -2348.663700  1317.592449  1573.370711    968.433347
# 1AO7_complex_102_roi -2320.804264  1377.532592  1576.326098    973.319917
# 1AO7_complex_103_roi -2357.738878  1138.079080  1576.689533    905.475965
# 1AO7_complex_104_roi -2294.067802  1222.838816  1549.443173    990.727833
# ...                           ...          ...          ...           ...
# 8YE4_complex_96_roi  -2316.242725  1182.359735  1564.471709   1482.574457
# 8YE4_complex_97_roi  -2321.771240  1489.747952  1577.282365   1515.148470
# 8YE4_complex_98_roi  -2322.922003  1257.006709  1570.692046    952.784107
# 8YE4_complex_99_roi  -2294.990194  1361.337270  1555.687776    946.197640
# 8YE4_complex_9_roi   -2338.500255  1306.585872  1591.853674    939.932423
#
#                       fa_intra_sol_xover4  lk_ball_wtd     fa_elec  pro_close  \
# ...

# %%
X = feature_df.values
y = score_df.DockQ.values

pls = PLSRegression(n_components=2)
pls.fit(X, y)

y_hat = pls.predict(X)
px.scatter(x=y, y=y_hat).show()
print(spearmanr(y, y_hat))
print(pearsonr(y, y_hat))
# Out:
# SignificanceResult(statistic=0.7670899001734434, pvalue=0.0)
# PearsonRResult(statistic=0.7273657925974372, pvalue=0.0)

# %%
result_df = score_df.copy()
result_df["dockq_hat"] = y_hat
result_df
# Out:
#                      pdb_id     DockQ        F1     iRMSD      LRMSD  \
# 1AO7_complex_100_roi   1AO7  0.486835  0.444444  2.763904   3.993340
# 1AO7_complex_101_roi   1AO7  0.343916  0.406250  4.034967   9.171524
# 1AO7_complex_102_roi   1AO7  0.336972  0.320000  4.525404   6.429585
# 1AO7_complex_103_roi   1AO7  0.566692  0.592593  2.071850   4.190820
# 1AO7_complex_104_roi   1AO7  0.381042  0.392857  4.343991   6.137761
# ...                     ...       ...       ...       ...        ...
# 8YE4_complex_96_roi    8YE4  0.199169  0.050000  4.276842   9.540469
# 8YE4_complex_97_roi    8YE4  0.290311  0.255319  4.007089   8.930815
# 8YE4_complex_98_roi    8YE4  0.130761  0.157895  6.957770  16.411849
# 8YE4_complex_99_roi    8YE4  0.123808  0.142857  8.743062  16.663863
# 8YE4_complex_9_roi     8YE4  0.091863  0.040000  7.638807  17.380767
#
#                           fnat  nat_correct  nat_total   fnonnat  \
# 1AO7_complex_100_roi  0.413793           12         29  0.520000
# ...

# %%
best_models = result_df.loc[result_df.groupby("pdb_id")["dockq_hat"].idxmax()]
best_models
# Out:
#                      pdb_id     DockQ        F1     iRMSD     LRMSD      fnat  \
# 1AO7_complex_54_roi    1AO7  0.390023  0.433333  3.743588  7.182035  0.448276
# 1G6R_complex_119_roi   1G6R  0.424561  0.514286  2.777763  7.319187  0.473684
# 1LP9_complex_6_roi     1LP9  0.885688  0.800000  0.918654  1.407539  0.956522
# 1MI5_complex_60_roi    1MI5  0.337607  0.166667  2.794662  7.097946  0.200000
# 1MWA_complex_106_roi   1MWA  0.453803  0.421053  2.688215  5.248375  0.400000
# ...                     ...       ...       ...       ...       ...       ...
# 8I5D_complex_108_roi   8I5D  0.417590  0.342857  2.805472  7.399057  0.461538
# 8SHI_complex_48_roi    8SHI  0.291354  0.142857  3.832835  7.543222  0.181818
# 8WTE_complex_33_roi    8WTE  0.237764  0.060606  5.087760  7.589660  0.076923
# 8WUL_complex_44_roi    8WUL  0.482327  0.333333  3.266837  5.703664  0.583333
# 8YE4_complex_34_roi    8YE4  0.387784  0.342857  2.599860  6.362792  0.272727
#
# ...

# %%
thresholds = [0.00, 0.23, 0.49, 0.80, 1.00]
for i in range(len(thresholds) - 1):
    print(len(best_models[(best_models.DockQ >= thresholds[i]) & (best_models.DockQ < thresholds[i + 1])]) / len(best_models))
# Out:
# 0.04522613065326633
# 0.4371859296482412
# 0.4221105527638191
# 0.09547738693467336

# %%
result_df = None
spearmans = dict()

for pdb_id in tqdm(score_df.pdb_id.unique()):

    X_train = feature_df[~feature_df.index.str.startswith(pdb_id)].values
    y_train = score_df[score_df.pdb_id != pdb_id].DockQ.values

    pls = PLSRegression(n_components=2)
    pls.fit(X_train, y_train)

    X_test = feature_df[feature_df.index.str.startswith(pdb_id)].values
    score_test_df = score_df[score_df.pdb_id == pdb_id]
    y_test = score_test_df.DockQ.values

    y_hat = pls.predict(X_test)
    score_test_df["dockq_hat"] = y_hat

    if result_df is None:
        result_df = score_test_df
    else:
        result_df = pd.concat([result_df, score_test_df])

    spearmans[pdb_id] = spearmanr(y_test, y_hat)[0]

spearman_df = pd.Series(spearmans)
# Out:
#   0%|          | 0/199 [00:00<?, ?it/s]/tmp/ipykernel_1276063/423226277.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   1%|          | 1/199 [00:00<00:23,  8.32it/s]/tmp/ipykernel_1276063/423226277.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   1%|          | 2/199 [00:00<00:23,  8.52it/s]/tmp/ipykernel_1276063/423226277.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
spearman_df.sort_values()
# Out:
# 3TF7   -0.407707
# 4JRY   -0.232299
# 8GOM   -0.172461
# 5SWS   -0.100051
# 7JWI   -0.071949
#           ...
# 2AK4    0.909936
# 3VXR    0.916490
# 1LP9    0.917839
# 2UWE    0.921333
# 3MV9    0.936292
# Length: 199, dtype: float64

# %%
result_df
# Out:
#                      pdb_id     DockQ        F1     iRMSD      LRMSD  \
# 1AO7_complex_100_roi   1AO7  0.486835  0.444444  2.763904   3.993340
# 1AO7_complex_101_roi   1AO7  0.343916  0.406250  4.034967   9.171524
# 1AO7_complex_102_roi   1AO7  0.336972  0.320000  4.525404   6.429585
# 1AO7_complex_103_roi   1AO7  0.566692  0.592593  2.071850   4.190820
# 1AO7_complex_104_roi   1AO7  0.381042  0.392857  4.343991   6.137761
# ...                     ...       ...       ...       ...        ...
# 8YE4_complex_96_roi    8YE4  0.199169  0.050000  4.276842   9.540469
# 8YE4_complex_97_roi    8YE4  0.290311  0.255319  4.007089   8.930815
# 8YE4_complex_98_roi    8YE4  0.130761  0.157895  6.957770  16.411849
# 8YE4_complex_99_roi    8YE4  0.123808  0.142857  8.743062  16.663863
# 8YE4_complex_9_roi     8YE4  0.091863  0.040000  7.638807  17.380767
#
#                           fnat  nat_correct  nat_total   fnonnat  \
# 1AO7_complex_100_roi  0.413793           12         29  0.520000
# ...

# %%
best_models = result_df.loc[result_df.groupby("pdb_id")["dockq_hat"].idxmax()]
best_models
# Out:
#                      pdb_id     DockQ        F1     iRMSD     LRMSD      fnat  \
# 1AO7_complex_129_roi   1AO7  0.373649  0.440000  3.613564  7.017795  0.379310
# 1G6R_complex_119_roi   1G6R  0.424561  0.514286  2.777763  7.319187  0.473684
# 1LP9_complex_6_roi     1LP9  0.885688  0.800000  0.918654  1.407539  0.956522
# 1MI5_complex_60_roi    1MI5  0.337607  0.166667  2.794662  7.097946  0.200000
# 1MWA_complex_106_roi   1MWA  0.453803  0.421053  2.688215  5.248375  0.400000
# ...                     ...       ...       ...       ...       ...       ...
# 8I5D_complex_108_roi   8I5D  0.417590  0.342857  2.805472  7.399057  0.461538
# 8SHI_complex_48_roi    8SHI  0.291354  0.142857  3.832835  7.543222  0.181818
# 8WTE_complex_33_roi    8WTE  0.237764  0.060606  5.087760  7.589660  0.076923
# 8WUL_complex_44_roi    8WUL  0.482327  0.333333  3.266837  5.703664  0.583333
# 8YE4_complex_34_roi    8YE4  0.387784  0.342857  2.599860  6.362792  0.272727
#
# ...

# %%
thresholds = [0.00, 0.23, 0.49, 0.80, 1.00]
for i in range(len(thresholds) - 1):
    print(len(best_models[(best_models.DockQ >= thresholds[i]) & (best_models.DockQ < thresholds[i + 1])]) / len(best_models))
# Out:
# 0.05025125628140704
# 0.4321608040201005
# 0.4221105527638191
# 0.09547738693467336
